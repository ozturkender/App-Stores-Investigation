# %% [markdown]
# # App Investigation
#
# In this project, We are going to analyze app date which includes many details about apps on AppStore and Goolge Play in order to form a better understanding of the relation between the genre of an app and the number of users of that particular app.
#
# Main purpose of this work is to create a solid proposal for the company about the type of a new app to be put in market based on the criterion that the company makes money from in-app adverts yielding the conclusion of more number of users mean more income.

# %%
from csv import reader

opened_file_AppStore = open("AppleStore.csv", encoding="utf8")
appStore_data = list (reader(opened_file_AppStore))

opened_file_GooglePlay = open("googleplaystore.csv", encoding="utf8")
googlePlay_data = list (reader(opened_file_GooglePlay))

# %%
# This function is to explore the data conveniently
def explore_data(dataset, start, end, rows_and_columns=False):
    dataset_slice = dataset[start:end]    
    for row in dataset_slice:
        print(row)
        print('\n') # adds a new (empty) line after each row

    if rows_and_columns:
        print('Number of rows:', len(dataset))
        print('Number of columns:', len(dataset[0]))

# %%
# First let us explore the column names for the datasets
print("AppStore Dataset Columns")
print(appStore_data[0])
print("\n")
print("GooglePlayStore Dataset Columns")
print(googlePlay_data[0])
# Out:
# AppStore Dataset Columns
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# GooglePlayStore Dataset Columns
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %% [markdown]
# -------------------
# It seems that two data sets have different column names but pretty much the same information. Although it seems self explanatory, you can find detailed information about the columns at links below.
#
# [AppStore](https://www.kaggle.com/ramamet4/app-store-apple-data-set-10k-apps/home)
#
# [GooglePlayStore](https://www.kaggle.com/lava18/google-play-store-apps/home)

# %%
explore_data(appStore_data[1:], 0,3,rows_and_columns=True)
# Out:
# ['1', '281656475', 'PAC-MAN Premium', '100788224', 'USD', '3.99', '21292', '26', '4', '4.5', '6.3.5', '4+', 'Games', '38', '5', '10', '1']
#
#
# ['2', '281796108', 'Evernote - stay organized', '158578688', 'USD', '0', '161065', '26', '4', '3.5', '8.2.2', '4+', 'Productivity', '37', '5', '23', '1']
#
#
# ['3', '281940292', 'WeatherBug - Local Weather, Radar, Maps, Alerts', '100524032', 'USD', '0', '188583', '2822', '3.5', '4.5', '5.0.0', '4+', 'Weather', '37', '5', '3', '1']
#
#
# Number of rows: 7197
# Number of columns: 17

# %%
explore_data(googlePlay_data[1:], 0, 3, rows_and_columns=True)
# Out:
# ['Photo Editor & Candy Camera & Grid & ScrapBook', 'ART_AND_DESIGN', '4.1', '159', '19M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0', '4.0.3 and up']
#
#
# ['Coloring book moana', 'ART_AND_DESIGN', '3.9', '967', '14M', '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play', 'January 15, 2018', '2.0.0', '4.0.3 and up']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# Number of rows: 10841
# Number of columns: 13

# %% [markdown]
# ## DATA CLEANING
# ### Line with missing information

# %%
# An issue has been observed in discussions at Kaggle that the entry 10472 has a missing column information. 
print(googlePlay_data[0])
print( "\n")
print(googlePlay_data[3])
print( "\n")
print(googlePlay_data[10473])
# It is seen below that "Life Made WI-Fi..." entry has no "Category" information and a columns shift occurs after.
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['U Launcher Lite – FREE Live Cool Themes, Hide Apps', 'ART_AND_DESIGN', '4.7', '87510', '8.7M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4', '4.0.3 and up']
#
#
# ['Life Made WI-Fi Touchscreen Photo Frame', '1.9', '19', '3.0M', '1,000+', 'Free', '0', 'Everyone', '', 'February 11, 2018', '1.0.19', '4.0 and up']

# %%
#Incorrect entry is deleted
del googlePlay_data[10473]

# %%
# Checked that deletion is in place
print(googlePlay_data[10473])
# Out:
# ['osmino Wi-Fi: free WiFi', 'TOOLS', '4.2', '134203', '4.1M', '10,000,000+', 'Free', '0', 'Everyone', 'Tools', 'August 7, 2018', '6.06.14', '4.4 and up']

# %% [markdown]
# ### Duplicated lines

# %%
# More on data explatory analysis, now we need to check any duplicated data for both appStore_data and googlePlay_data

unique_appStore =[]
duplicated_appStore = []

for app in appStore_data[1:]:
    #app[2] includes name of the app in appStore_data
    if app[2] in unique_appStore:
        duplicated_appStore.append(app[2])
    else:
        unique_appStore.append(app[2])
        
unique_googlePlayStore =[]
duplicated_googlePlayStore = []

for app in googlePlay_data[1:]:
    #app[0] includes name of the app in googlePlay_data
    if app[0] in unique_googlePlayStore:
        duplicated_googlePlayStore.append(app[0])
    else:
        unique_googlePlayStore.append(app[0])

# %%
print(len(duplicated_appStore))
print("\n")
print(duplicated_appStore)

# It is observed that there are two duplicated entries in appStore_data. However, it is confirmed from 
# documentation page that those are different apps with different producers but same names.
# Out:
# 2
#
#
# ['VR Roller Coaster', 'Mannequin Challenge']

# %%
len(duplicated_googlePlayStore)
#The duplication case is different in googlePlayStore date. We need to deal with these duplications.
# Out:
# 1181

# %%
# One example is chosen to illustrate the duplication. Let us pick the 1000th entry of duplicated_googlePlayStore list.
# We will also print the header for convenience

dup_android = duplicated_googlePlayStore[1000]
print(googlePlay_data[0])

for app in googlePlay_data[1:]:
    if app[0] == dup_android:
        print("\n")   
        print(app)
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']
#
#
# ['Moco - Chat, Meet People', 'DATING', '4.2', '313724', 'Varies with device', '10,000,000+', 'Free', '0', 'Mature 17+', 'Dating', 'August 4, 2018', '2.6.141', '4.1 and up']
#
#
# ['Moco - Chat, Meet People', 'DATING', '4.2', '313724', 'Varies with device', '10,000,000+', 'Free', '0', 'Mature 17+', 'Dating', 'August 4, 2018', '2.6.141', '4.1 and up']
#
#
# ['Moco - Chat, Meet People', 'DATING', '4.2', '313769', 'Varies with device', '10,000,000+', 'Free', '0', 'Mature 17+', 'Dating', 'August 4, 2018', '2.6.142', '4.1 and up']

# %%
# The difference between lines are "Reviews" columns. Appearently, the date has been retrieved from Google Playstore
# at different time instances. It is possible to randomly remove the duplicated lines but keeping the line that has
# the highest "Reviews" count seems a better idea. 

reviews_max = {}

for app in googlePlay_data[1:]:
        #app[0] includes the name of the app
        name = app[0]
        n_reviews = float(app[3])
        
        if (name in reviews_max and reviews_max[name]<n_reviews) or (name not in reviews_max):
            reviews_max[name]=n_reviews

# %%
#There were 10840 total apps in googlePlay_data and 1181 of them were duplicates, which end up with 9656 unique data.
len(reviews_max)
# Out:
# 9659

# %%
# Now is the time to remove the duplicated data

googlePlay_data_CLEANED = []
already_added = []

for app in googlePlay_data[1:]:
    name = app[0]
    n_reviews = float(app[3])
    
    if (reviews_max[name] == n_reviews) and (name not in already_added):
        # since some of the duplicated apps have the same number of reviews (a full duplicate) this second condition should
        # be added.
        googlePlay_data_CLEANED.append(app)
        already_added.append(name)
        
len(googlePlay_data_CLEANED)
# The duplicated data seems to be removed, but just to make sure, we will apply the same algorithm above to CLEANED data
# Out:
# 9659

# %%
unique_googlePlayStore_CLEANED =[]
duplicated_googlePlayStore_CLEANED = []

for app in googlePlay_data_CLEANED[1:]:
    #app[0] includes name of the app in googlePlay_data
    if app[0] in unique_googlePlayStore_CLEANED:
        duplicated_googlePlayStore_CLEANED.append(app[0])
    else:
        unique_googlePlayStore_CLEANED.append(app[0])
        
len(duplicated_googlePlayStore_CLEANED)
# As it is seen, there is no duplicated data left.
# Out:
# 0

# %% [markdown]
# ### Cleaning Non-English Apps

# %%
# We observed some apps are not for English speaking customers which we do not interested in. In order to clean them out,
# first we need to write a function to identify if there is a non-English letter in the string passed in.

def check_English(string):
    counter = 0
    for letter in string:
        
        if ord(letter)>127:
            counter +=1
    if counter >3:
        return False
    else:
        return True

# %%
# We should apply the check_English function to two of our datasets. We will create new sets for English apps.
appStore_data_ENG = []

for app in appStore_data[1:]: #title row still in place
    name = app[2]  #name of the app is at 3rd index for appStore_data
    if check_English(name):
        appStore_data_ENG.append(app)

googlePlay_data_CLEANED_ENG = []
for app in googlePlay_data_CLEANED: # title row is not in place
    name = app[0]  #name of the app is at 1st index for googlePlay_data
    if check_English(name):
        googlePlay_data_CLEANED_ENG.append(app)

print ("English apps at Appstore is " + str(len(appStore_data_ENG)) +"\n")
print ("Non-Engish apps at Appstore is " + str(len(appStore_data)-len(appStore_data_ENG)-1)+ "\n") #title row should be subtracted
print ("English apps at Google PlayStore is " +str(len(googlePlay_data_CLEANED_ENG))+"\n")
print ("Non-Engish apps at Google PlayStore is " + str(len(googlePlay_data_CLEANED)-len(googlePlay_data_CLEANED_ENG))+ "\n")

# Notice that both of last datasets do not include title rows
# Out:
# English apps at Appstore is 6183
#
# Non-Engish apps at Appstore is 1014
#
# English apps at Google PlayStore is 9614
#
# Non-Engish apps at Google PlayStore is 45

# %%
# Now is the time to filter non-free apps
appStore_data_ENG_FREE = []
for app in appStore_data_ENG:
    price = float(app[5])    # price information is at index 5 for appStore data
    if price == 0:
        appStore_data_ENG_FREE.append(app)

googlePlay_data_CLEANED_ENG_FREE = []
for app in googlePlay_data_CLEANED_ENG:
    price = app[7]    # price information is at index 7 for googlePlaystore data, first character ($) excluded if not free
    if price[0] == "$":
        price = float(price[1:])
    else:
        price = float(price)
    
    if price == 0:
        googlePlay_data_CLEANED_ENG_FREE.append(app)
        
print ("Free and English apps at Appstore is " + str(len(appStore_data_ENG_FREE)) +"\n")
print ("Non-free and English apps at Appstore is " + str(len(appStore_data_ENG)-len(appStore_data_ENG_FREE))+ "\n")
print ("Free and English apps at Google PlayStore is " +str(len(googlePlay_data_CLEANED_ENG_FREE))+"\n")
print ("Non-free and English apps at Google PlayStore is " + str(len(googlePlay_data_CLEANED_ENG)-len(googlePlay_data_CLEANED_ENG_FREE))+ "\n")
# Out:
# Free and English apps at Appstore is 3222
#
# Non-free and English apps at Appstore is 2961
#
# Free and English apps at Google PlayStore is 8864
#
# Non-free and English apps at Google PlayStore is 750

# %% [markdown]
# ### App Profile Criteria
# The purpose of this work is to define a profile of apps that are mostly prefered by the users, since our company produces free to download apps and make money from in-app ads. In order to reach as much customers as possible, we need to define a profile which is successful on both markets (AppStore and Google Play). Now first, we need to find which columns should be used to understand which genres exist in stores most.

# %%
# Title columns are given to find the appropriate columns including genre information
print("AppStore Dataset Columns")
print(appStore_data[0])
print("\n")
print("GooglePlayStore Dataset Columns")
print(googlePlay_data[0])
# Out:
# AppStore Dataset Columns
# ['', 'id', 'track_name', 'size_bytes', 'currency', 'price', 'rating_count_tot', 'rating_count_ver', 'user_rating', 'user_rating_ver', 'ver', 'cont_rating', 'prime_genre', 'sup_devices.num', 'ipadSc_urls.num', 'lang.num', 'vpp_lic']
#
#
# GooglePlayStore Dataset Columns
# ['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver', 'Android Ver']

# %%
# "prime genre" at AppStore and "Category" and "Genres" columns at Google Play data seem appropriate
# First we will create a function, taking a dataset and an index as parameter and returns the frequency table in dict form
# if "title_row" is True, function excludes it
def freq_table(dataset, index, title_row = False):
    
    if title_row:
        dataset=dataset[1:]
    my_dict = {}
    for lst in dataset:
        if lst[index] in my_dict:
            my_dict[lst[index]] +=1
        else:
            my_dict[lst[index]] = 1
    return my_dict

# %%
# This function is to conveniently sort and display frequency tables
def display_table(dataset, index):
    table = freq_table(dataset, index)
    table_display = []
    for key in table:
        key_val_as_tuple = (table[key], key)
        table_display.append(key_val_as_tuple)

    table_sorted = sorted(table_display, reverse = True)
    for entry in table_sorted:
        print(entry[1], ':', entry[0])

# %%
# Frequency tables for appStore "prime genre" column and google Play "Category" and "Genres" columns
print("APPSTORE 'PRIME GENRE' FREQUENCY TABLE")
display_table (appStore_data_ENG_FREE,12)
# Out:
# APPSTORE 'PRIME GENRE' FREQUENCY TABLE
# Games : 1874
# Entertainment : 254
# Photo & Video : 160
# Education : 118
# Social Networking : 106
# Shopping : 84
# Utilities : 81
# Sports : 69
# Music : 66
# Health & Fitness : 65
# Productivity : 56
# Lifestyle : 51
# News : 43
# Travel : 40
# Finance : 36
# Weather : 28
# Food & Drink : 26
# Reference : 18
# Business : 17
# Book : 14
# Navigation : 6
# Medical : 6
# Catalogs : 4

# %% [markdown]
# The mostly existing free english apps are "games" in Appstore. The runner-up genre is "Entertainment" and is way behind. The difference between the first and the second is much higher than the difference between the second and the rest. In general, one can say that app store is dominated by apps produced for enternetainment purposes (Games, Entertainment, Photo & Video, Social Networking, Music, Sports etc) rather than practical purposes (education, shopping, utilities, productivity etc. Although, existence of a particular genre does not necessitate higher number of downloads, the existence of a correlation is undeniable.

# %%
print("GOOGLE PLAYSTORE 'CATEGORY' FREQUENCY TABLE")
display_table (googlePlay_data_CLEANED_ENG_FREE,1)
# Out:
# GOOGLE PLAYSTORE 'CATEGORY' FREQUENCY TABLE
# FAMILY : 1676
# GAME : 862
# TOOLS : 750
# BUSINESS : 407
# LIFESTYLE : 346
# PRODUCTIVITY : 345
# FINANCE : 328
# MEDICAL : 313
# SPORTS : 301
# PERSONALIZATION : 294
# COMMUNICATION : 287
# HEALTH_AND_FITNESS : 273
# PHOTOGRAPHY : 261
# NEWS_AND_MAGAZINES : 248
# SOCIAL : 236
# TRAVEL_AND_LOCAL : 207
# SHOPPING : 199
# BOOKS_AND_REFERENCE : 190
# DATING : 165
# VIDEO_PLAYERS : 159
# MAPS_AND_NAVIGATION : 124
# FOOD_AND_DRINK : 110
# EDUCATION : 103
# ENTERTAINMENT : 85
# LIBRARIES_AND_DEMO : 83
# AUTO_AND_VEHICLES : 82
# HOUSE_AND_HOME : 73
# WEATHER : 71
# EVENTS : 63
# PARENTING : 58
# ART_AND_DESIGN : 57
# COMICS : 55
# BEAUTY : 53

# %% [markdown]
# Google Playstore data "CATEGORY" column give a rather different pattern. At this frequency table, "FAMILY" genre apps have the majority followed by "GAMES". Practical purpose apps have higher frequency in general at Google Play Store. Although a corelation is expected between these frequencies and number of downloads, the level of that corelation should be further investigated.

# %%
print("GOOGLE PLAYSTORE 'GENRES' FREQUENCY TABLE")
display_table (googlePlay_data_CLEANED_ENG_FREE,9)
# Out:
# GOOGLE PLAYSTORE 'GENRES' FREQUENCY TABLE
# Tools : 749
# Entertainment : 538
# Education : 474
# Business : 407
# Productivity : 345
# Lifestyle : 345
# Finance : 328
# Medical : 313
# Sports : 307
# Personalization : 294
# Communication : 287
# Action : 275
# Health & Fitness : 273
# Photography : 261
# News & Magazines : 248
# Social : 236
# Travel & Local : 206
# Shopping : 199
# Books & Reference : 190
# Simulation : 181
# Dating : 165
# Arcade : 164
# Video Players & Editors : 157
# Casual : 156
# Maps & Navigation : 124
# Food & Drink : 110
# Puzzle : 100
# Racing : 88
# Role Playing : 83
# Libraries & Demo : 83
# Auto & Vehicles : 82
# Strategy : 81
# House & Home : 73
# Weather : 71
# Events : 63
# Adventure : 60
# Comics : 54
# Beauty : 53
# Art & Design : 53
# Parenting : 44
# Card : 40
# Casino : 38
# Trivia : 37
# Educational;Education : 35
# Board : 34
# Educational : 33
# Education;Education : 30
# Word : 23
# Casual;Pretend Play : 21
# Music : 18
# Racing;Action & Adventure : 15
# Puzzle;Brain Games : 15
# Entertainment;Music & Video : 15
# Casual;Brain Games : 12
# Casual;Action & Adventure : 12
# Arcade;Action & Adventure : 11
# Action;Action & Adventure : 9
# Educational;Pretend Play : 8
# Simulation;Action & Adventure : 7
# Parenting;Education : 7
# Entertainment;Brain Games : 7
# Board;Brain Games : 7
# Parenting;Music & Video : 6
# Educational;Brain Games : 6
# Casual;Creativity : 6
# Art & Design;Creativity : 6
# Education;Pretend Play : 5
# Role Playing;Pretend Play : 4
# Education;Creativity : 4
# Role Playing;Action & Adventure : 3
# Puzzle;Action & Adventure : 3
# Entertainment;Creativity : 3
# Entertainment;Action & Adventure : 3
# Educational;Creativity : 3
# Educational;Action & Adventure : 3
# Education;Music & Video : 3
# Education;Brain Games : 3
# Education;Action & Adventure : 3
# Adventure;Action & Adventure : 3
# Video Players & Editors;Music & Video : 2
# Sports;Action & Adventure : 2
# Simulation;Pretend Play : 2
# Puzzle;Creativity : 2
# Music;Music & Video : 2
# Entertainment;Pretend Play : 2
# Casual;Education : 2
# Board;Action & Adventure : 2
# Video Players & Editors;Creativity : 1
# Trivia;Education : 1
# Travel & Local;Action & Adventure : 1
# Tools;Education : 1
# Strategy;Education : 1
# Strategy;Creativity : 1
# Strategy;Action & Adventure : 1
# Simulation;Education : 1
# Role Playing;Brain Games : 1
# Racing;Pretend Play : 1
# Puzzle;Education : 1
# Parenting;Brain Games : 1
# Music & Audio;Music & Video : 1
# Lifestyle;Pretend Play : 1
# Lifestyle;Education : 1
# Health & Fitness;Education : 1
# Health & Fitness;Action & Adventure : 1
# Entertainment;Education : 1
# Communication;Creativity : 1
# Comics;Creativity : 1
# Casual;Music & Video : 1
# Card;Action & Adventure : 1
# Books & Reference;Education : 1
# Art & Design;Pretend Play : 1
# Art & Design;Action & Adventure : 1
# Arcade;Pretend Play : 1
# Adventure;Education : 1

# %% [markdown]
# "GENRES" column of Google Play dataset gives a similar pattern as the "CATEGORY" column. On the other hand, this column is constituted as naming sub-branches as different genres (i.e. there are many items including Education as well as only Education itself). Therefore this frequency is not useful in that sense.
#
# __As a result, it is not convenient to offer a certain genre type with the above information.__
#
# ### App Store Popularity Analysis
#
# To make a more decent offer, average number of downloads for each genre should be examined. Since such information does not exist in App Store data, "rating_count_tot" columns which gives the total number of ratings for a certain app, will be used.

# %%
freq_table_appStore = freq_table (appStore_data_ENG_FREE,12)

app_Store_rating_tot = {}

for app in appStore_data_ENG_FREE:
    genre = app[12]    # prime genre data is at index 12 of appStore data
    if genre in app_Store_rating_tot:
        app_Store_rating_tot[genre] += float(app[6])    # rating_count_tot is at index 6 of appStore data
    else:
        app_Store_rating_tot[genre] = float(app[6])

app_Store_rating_avg = {}
for item in app_Store_rating_tot:
    app_Store_rating_avg[item] = app_Store_rating_tot[item] / freq_table_appStore [item]

# %%
app_Store_rating_avg
# Out:
# {'Productivity': 21028.410714285714,
#  'Weather': 52279.892857142855,
#  'Shopping': 26919.690476190477,
#  'Reference': 74942.11111111111,
#  'Finance': 31467.944444444445,
#  'Music': 57326.530303030304,
#  'Utilities': 18684.456790123455,
#  'Travel': 28243.8,
#  'Social Networking': 71548.34905660378,
#  'Sports': 23008.898550724636,
#  'Health & Fitness': 23298.015384615384,
#  'Games': 22788.6696905016,
#  'Food & Drink': 33333.92307692308,
#  'News': 21248.023255813954,
#  'Book': 39758.5,
#  'Photo & Video': 28441.54375,
#  'Entertainment': 14029.830708661417,
#  'Business': 7491.117647058823,
#  'Lifestyle': 16485.764705882353,
#  'Education': 7003.983050847458,
#  'Navigation': 86090.33333333333,
#  'Medical': 612.0,
#  'Catalogs': 4004.0}

# %% [markdown]
# The highest number of ratings is on Navigation genre. However this is mainly because of a couple of very popular navigation apps like GoogleMaps and Waze

# %%
for app in appStore_data_ENG_FREE:
    if app[12] == "Navigation":
        print(app[2] + " : " + app[6])
# Out:
# Waze - GPS Navigation, Maps & Real-time Traffic : 345046
# Geocaching® : 12811
# ImmobilienScout24: Real Estate Search in Germany : 187
# Railway Route Search : 5
# CoPilot GPS – Car Navigation & Offline Maps : 3582
# Google Maps - Navigation & Transit : 154911

# %%
#Second most popular genre is "Reference".
for app in appStore_data_ENG_FREE:
    if app[12] == "Reference":
        print(app[2] + " : " + app[6])
# Out:
# Bible : 985920
# Dictionary.com Dictionary & Thesaurus : 200047
# Dictionary.com Dictionary & Thesaurus for iPad : 54175
# Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran : 18418
# Merriam-Webster Dictionary : 16849
# Google Translate : 26786
# Night Sky : 12122
# WWDC : 762
# Jishokun-Japanese English Dictionary & Translator : 0
# 教えて!goo : 0
# VPN Express : 14
# New Furniture Mods - Pocket Wiki & Game Tools for Minecraft PC Edition : 17588
# LUCKY BLOCK MOD ™ for Minecraft PC Edition - The Best Pocket Wiki & Mods Installer Tools : 4693
# Guides for Pokémon GO - Pokemon GO News and Cheats : 826
# Horror Maps for Minecraft PE - Download The Scariest Maps for Minecraft Pocket Edition (MCPE) Free : 718
# City Maps for Minecraft PE - The Best Maps for Minecraft Pocket Edition (MCPE) : 8535
# GUNS MODS for Minecraft PC Edition - Mods Tools : 1497
# Real Bike Traffic Rider Virtual Reality Glasses : 8

# %% [markdown]
# With regards to "Reference" apps, the situation is pretty much the same with "Navigation" apps. Namely, the most popular books in the world have already been allocated with other apps and the books that does not have much popularity have quite low amount of ratings.
#
# Third most popular genre is "Social Networking" whose average has been heavily influenced by Pinterest, Facebook and Skype.
# On the other hand, I see a potential on "Games" apps

# %%
#Second most popular genre is "Social Networking".
for app in appStore_data_ENG_FREE:
    if app[12] == "Games":
        print(app[2] + " : " + app[6])
# Out:
# Hangman. : 42316
# Blackjack by MobilityWare : 180087
# PAC-MAN : 508808
# Beer Pong Game : 187315
# NYTimes Crossword - Daily Word Puzzle Game : 53465
# Sky Burger - Build & Match Food Free : 114096
# Pixel Starships™ : 8Bit MMORPG : 5565
# Angry Birds : 824451
# Glow Hockey 2 FREE : 186653
# Solitaire : 679055
# Angry Birds HD : 89110
# ▻Sudoku : 359832
# Virtual Regatta Offshore : 209
# Jenga : 32527
# Spider Solitaire Free by MobilityWare : 128739
# Angry Birds Seasons HD : 75714
# Fruit Ninja® : 327025
# Temple Run : 1724546
# Angry Birds Rio : 170843
# Angry Birds Rio HD : 70122
# My Horse : 293857
# Tiny Tower - Free City Building : 414803
# ROBLOX : 183621
# Nyan Cat: Lost In Space : 76392
# Fishing Kings Free+ : 35058
# Werewolf "Nightmare in Prison" : 78
# Magic Jigsaw Puzzles : 187666
# DragonVale : 503230
# Racing Penguin Free - Top Flying and Diving Game : 141224
# Phoenix HD : 13106
# Sonic CD : 16358
# White Tiles 2 : Piano Master ( Don't Hit The White Tiles 4 ) - Free Music Game : 60
# Doodle Jump FREE - BE WARNED: Insanely addictive : 28153
# Jetpack Joyride : 405647
# Top Eleven 2017 - Be a Soccer Manager : 14104
# Kids Doodle - Movie Kids Color & Draw : 8025
# Zen Pinball : 6534
# The Sims™ FreePlay : 446880
# CSR Racing : 677247
# Bejeweled Blitz : 221002
# Haunted Halloween Escape : 11945
# ⋆Solitaire : 106398
# Bejeweled Classic : 183259
# TETRIS® FREE : 3383
# DoubleDown Casino & Slots  – Vegas Slot Machines! : 101599
# Lep's World Free - platformer games : 38075
# Head Soccer : 481564
# Fresh Tracks Snowboarding : 10107
# LEGO® Juniors Create & Cruise : 6152
# Sweet Tales : 147
# Buzzy Bubbles : 13
# ZenDots 2 - One Dot’s Journey : 54
# Hat Trick Shots : 197
# SMILE Inc. : 25859
# Water Bottle Flip Challenge: Flippy Bottle Diving : 362
# ON-SEN - escape game - : 14
# Flip King : 72
# Solitaire One : 1740
# Shoutrageous! - The Addictive Game of Lists : 60
# Escape from the Bears of the student council room. : 0
# Super Jabber Jump : 612
# Epic Battle Simulator : 1647
# Escape Game: Red room : 5
# Escape a Halloween Candy Shop : 0
# Our dark lord-Sasuyu 2-TAP RPG : 35
# Race Driving School Car Racing Driver License Test : 37
# Dungeon Witcher : 5
# My First Crush - High School Love : 710
# Crazy Clown Chase : 778
# Fitness Girl - Dance and Play at the Gym : 913
# Demi Lovato - Zombarazzie Adventure : 690
# Keepy Ducky : 1083
# Monster Zombie Plague War - Virtual Reality (VR) : 12
# Golden Lotus Slots : 0
# Waiit : 35
# Juju on the Beat : 2772
# Wall Switch : 19
# Cubed Rally World : 14
# Room Escape Game - Pictures Room Esacpe : 6
# Shark Boom - Challenge Friends with your Pet : 0
# Spiral Tower : 78
# Paper.io : 24097
# Juju on that Beat Challenge : 10
# ImpossibleGO! - You can't clear : 0
# Haunted Rooms: Escape VR Game for Google Cardboard : 60
# IQ200 - If you can clear all stage : 1
# Nope Quiz : 61
# Flip : 230
# Juju On That Beat  - Dance Challenge Game : 21
# Mannequin Challenge : 668
# Linda Brown: Interactive Story : 537
# Ocean Overlord - Global War : 0
# Hovercrash : 41
# Book - room escape game - : 10
# Icarus - A Star's Journey : 230
# Escape a Crepe House : 3
# Top Tier : 48
# Fast Food Rampage : 281
# Ice Princess - Royal Wedding Day : 283
# Amusement Park Tour 2: Fun Xmas : 115
# Sweet Tales: Match 3 Christmas : 215
# Escape Game: Christmas Eve : 21
# Stickman Base Jumper 2 : 1362
# Mannequin Challenge : 105
# Bottle Flip! : 3384
# Ao Oni2 : 7
# Multi Level Car Parking 6 Shopping Mall Garage Lot : 162
# Valley of Fear Virtual Reality : 46
# Christmas Swap 3 -Match toy & candy to countdown : 96
# VR Horror Maze Walk :Horror Fever For VR Cardboard : 6
# 4x4 Dirt Track Trials Forest Driving Parking Sim : 1441
# Escape from the frigid Igloo. : 3
# Room Escape Game - Santa's Room : 10
# VR Thrills: Roller Coaster 360 (Google Cardboard) : 14
# Santa Kids Hair Salon - Christmas Makeover Games : 41
# Human Juggling Cup : 0
# Again - room escape game : 11
# Escape Game: illumination : 23
# Demolition Derby Virtual Reality (VR) Racing : 18
# Kubik : 142
# VR Roller-Coaster : 30
# VR Roller Coaster World - Virtual Reality : 85
# Escape the Sweet Shop Series : 3

# %% [markdown]
# There are not any highly popular and hard to compete game apps and the average rating numbers are more or less balanced. Besides, building a Game app idea fits the general tendency in App Store being dominated by entertainment apps. People's gaming tastes may differ widely and we think that there could be found some room for a new and popular app.
#
# ### Google Play Store Popularity Analysis
# Now is the time to analyize Play Store data. We will use "Category" column for the genre information.
#
# Although there is a distinct "Installs" column in Google Play, the data is not precise. However, for our purpose, exact precision is not needed. Considering 100,000+ downloads as 100.000 will be more than enough.

# %%
print(googlePlay_data_CLEANED_ENG_FREE[454][5])
# Out:
# 100+

# %%
display_table(googlePlay_data_CLEANED_ENG_FREE, 5)
# Out:
# 1,000,000+ : 1394
# 100,000+ : 1024
# 10,000,000+ : 935
# 10,000+ : 904
# 1,000+ : 744
# 100+ : 613
# 5,000,000+ : 605
# 500,000+ : 493
# 50,000+ : 423
# 5,000+ : 400
# 10+ : 314
# 500+ : 288
# 50,000,000+ : 204
# 100,000,000+ : 189
# 50+ : 170
# 5+ : 70
# 1+ : 45
# 500,000,000+ : 24
# 1,000,000,000+ : 20
# 0+ : 4
# 0 : 1

# %%
# We should first get rid of plus signs and commas in order to convert the "Installs" column into float.
# We will use str.replace method for this purpose.

googlePlay_data_CLEANED_ENG_FREE_INSTALLS = []
for app in googlePlay_data_CLEANED_ENG_FREE:
    app[5]=app[5].replace("+","")
    app[5]=float(app[5].replace(",",""))
    
    googlePlay_data_CLEANED_ENG_FREE_INSTALLS.append(app)
display_table(googlePlay_data_CLEANED_ENG_FREE_INSTALLS, 5)
# Out:
# 1000000.0 : 1394
# 100000.0 : 1024
# 10000000.0 : 935
# 10000.0 : 904
# 1000.0 : 744
# 100.0 : 613
# 5000000.0 : 605
# 500000.0 : 493
# 50000.0 : 423
# 5000.0 : 400
# 10.0 : 314
# 500.0 : 288
# 50000000.0 : 204
# 100000000.0 : 189
# 50.0 : 170
# 5.0 : 70
# 1.0 : 45
# 500000000.0 : 24
# 1000000000.0 : 20
# 0.0 : 5

# %%
# Since all number of installs are float type, we can calculate average downloads with this data, just like how we did for Apple Store data.
freq_table_googlePlay = freq_table (googlePlay_data_CLEANED_ENG_FREE,1)

googlePlay_installs_tot = {}

for app in googlePlay_data_CLEANED_ENG_FREE_INSTALLS:
    category = app[1]    # Category data is at index 1 of google Playstore data
    if category in googlePlay_installs_tot:
        googlePlay_installs_tot[category] += app[5]    # installs is at index 5 of google playstore data
    else:
        googlePlay_installs_tot[category] = app[5]

googlePlay_installs_avg = {}
for item in googlePlay_installs_tot:
    googlePlay_installs_avg[item] = googlePlay_installs_tot[item] / freq_table_googlePlay [item]
    
googlePlay_installs_avg
# Out:
# {'ART_AND_DESIGN': 1986335.0877192982,
#  'AUTO_AND_VEHICLES': 647317.8170731707,
#  'BEAUTY': 513151.88679245283,
#  'BOOKS_AND_REFERENCE': 8767811.894736841,
#  'BUSINESS': 1712290.1474201474,
#  'COMICS': 817657.2727272727,
#  'COMMUNICATION': 38456119.167247385,
#  'DATING': 854028.8303030303,
#  'EDUCATION': 1833495.145631068,
#  'ENTERTAINMENT': 11640705.88235294,
#  'EVENTS': 253542.22222222222,
#  'FINANCE': 1387692.475609756,
#  'FOOD_AND_DRINK': 1924897.7363636363,
#  'HEALTH_AND_FITNESS': 4188821.9853479853,
#  'HOUSE_AND_HOME': 1331540.5616438356,
#  'LIBRARIES_AND_DEMO': 638503.734939759,
#  'LIFESTYLE': 1437816.2687861272,
#  'GAME': 15588015.603248259,
#  'FAMILY': 3695641.8198090694,
#  'MEDICAL': 120550.61980830671,
#  'SOCIAL': 23253652.127118643,
#  'SHOPPING': 7036877.311557789,
#  'PHOTOGRAPHY': 17840110.40229885,
#  'SPORTS': 3638640.1428571427,
#  'TRAVEL_AND_LOCAL': 13984077.710144928,
#  'TOOLS': 10801391.298666667,
#  'PERSONALIZATION': 5201482.6122448975,
#  'PRODUCTIVITY': 16787331.344927534,
#  'PARENTING': 542603.6206896552,
#  'WEATHER': 5074486.197183099,
#  'VIDEO_PLAYERS': 24727872.452830188,
#  'NEWS_AND_MAGAZINES': 9549178.467741935,
#  'MAPS_AND_NAVIGATION': 4056941.7741935486}

# %% [markdown]
# The most installed genres are "COMMUNICATION", "VIDEO PLAYERS", "SOCIAL", "PHOTOGRAPHY", "TOOLS", "GAME", "ENTERTAINMENT" and "NEWS_AND_MAGAZINES".
#
# First 5 of those genres are dominated by apps like Youtube, Whatsapp, Instagram, Google Photos, Google etc. To compete those apps are far beyond our company's ability. However on the other hand, gameing apps are in wide variaty and the number of downloads are balanced. We think that there is a room for this genre and it might be possible for such an app to be succesfull on both Google Play Store and App Store.

# %%
for app in googlePlay_data_CLEANED_ENG_FREE_INSTALLS:
    if app[1] == "GAME":
        print(app[0] + " : " + str(app[5]))
# Out:
# Solitaire : 10000000.0
# Sonic Dash : 100000000.0
# PAC-MAN : 100000000.0
# Bubble Witch 3 Saga : 50000000.0
# Race the Traffic Moto : 10000000.0
# Marble - Temple Quest : 10000000.0
# Shooting King : 10000000.0
# Geometry Dash World : 10000000.0
# Jungle Marble Blast : 5000000.0
# Roll the Ball® - slide puzzle : 100000000.0
# Block Craft 3D: Building Simulator Games For Free : 50000000.0
# Farm Fruit Pop: Party Time : 1000000.0
# Love Balls : 50000000.0
# Piano Tiles 2™ : 100000000.0
# Pokémon GO : 100000000.0
# Paint Hit : 10000000.0
# Snake VS Block : 50000000.0
# Rolly Vortex : 10000000.0
# Woody Puzzle : 1000000.0
# Stack Jump : 10000000.0
# The Cube : 5000000.0
# Extreme Car Driving Simulator : 100000000.0
# Bricks n Balls : 1000000.0
# The Fish Master! : 1000000.0
# Color Road : 10000000.0
# Draw In : 10000000.0
# PLANK! : 500000.0
# Looper! : 1000000.0
# Trivia Crack : 100000000.0
# Will it Crush? : 5000000.0
# Tomb of the Mask : 5000000.0
# Baseball Boy! : 10000000.0
# Hello Stars : 10000000.0
# Tank Stars : 10000000.0
# Hole.io : 10000000.0
# Mini Golf King - Multiplayer Game : 5000000.0
# Flip the Gun - Simulator Game : 10000000.0
# Mad Skills BMX 2 : 1000000.0
# MMX Hill Dash 2 – Offroad Truck, Car & Bike Racing : 1000000.0
# Word Link : 10000000.0
# Last Day on Earth: Survival : 10000000.0
# Partymasters - Fun Idle Game : 10000000.0
# Harry Potter: Hogwarts Mystery : 10000000.0
# Offroad Outlaws : 1000000.0
# Grim Soul: Dark Fantasy Survival : 5000000.0
# Disney Heroes: Battle Mode : 5000000.0
# New YAHTZEE® With Buddies Dice Game : 5000000.0
# Word Crossy - A crossword game : 5000000.0
# MLB TAP SPORTS BASEBALL 2018 : 1000000.0
# Hero Hunters : 5000000.0
# Cooking Madness - A Chef's Restaurant Games : 10000000.0
# Ice Crush 2018 - A new Puzzle Matching Adventure : 1000000.0
# TerraGenesis - Space Colony : 1000000.0
# SHADOWGUN LEGENDS : 1000000.0
# RULES OF SURVIVAL : 10000000.0
# Mafia City : 10000000.0
# Cash, Inc. Money Clicker Game & Business Adventure : 10000000.0
# Dino War: Rise of Beasts : 1000000.0
# Tokyo Ghoul: Dark War : 1000000.0
# Last Shelter: Survival : 5000000.0
# Guns of Glory : 10000000.0
# Lineage 2: Revolution : 5000000.0
# Final Fantasy XV: A New Empire : 10000000.0
# Girls' Frontline : 100000.0
# Chapters: Interactive Stories : 1000000.0
# Honkai Impact 3rd : 1000000.0
# Master of Eternity(MOE) : 100000.0
# Angry Birds 2 : 100000000.0
# PUBG MOBILE : 50000000.0
# The Sims™ FreePlay : 10000000.0
# Best Fiends - Free Puzzle Game : 10000000.0
# Jurassic World™ Alive : 5000000.0
# Choices: Stories You Play : 10000000.0
# Solitaire TriPeaks : 10000000.0
# Merge Dragons! : 5000000.0
# The Walking Dead: Road to Survival : 10000000.0
# Hustle Castle: Fantasy Kingdom : 10000000.0
# Might & Magic: Elemental Guardians : 500000.0
# Game of Thrones: Conquest™ : 1000000.0
# Love Nikki-Dress UP Queen : 5000000.0
# Summoners War : 50000000.0
# FINAL FANTASY BRAVE EXVIUS : 5000000.0
# Fate/Grand Order (English) : 500000.0
# Lords Mobile: Battle of the Empires - Strategy RPG : 50000000.0
# War and Order : 5000000.0
# Candy Crush Saga : 500000000.0
# 8 Ball Pool : 100000000.0
# Subway Surfers : 1000000000.0
# Candy Crush Soda Saga : 100000000.0
# Toon Blast : 10000000.0
# Toy Blast : 50000000.0
# Clash Royale : 100000000.0
# Clash of Clans : 100000000.0
# Plants vs. Zombies FREE : 100000000.0
# Block Puzzle : 5000000.0
# Super Jim Jump - pixel 3d : 1000000.0
# Pou : 500000000.0
# Flow Free : 100000000.0
# Homescapes : 10000000.0
# Wordscapes : 10000000.0
# My Talking Angela : 100000000.0
# slither.io : 100000000.0
# Cooking Fever : 100000000.0
# Yes day : 100000000.0
# Gardenscapes : 50000000.0
# Fishdom : 10000000.0
# Galaxy Attack: Alien Shooter : 10000000.0
# Score! Hero : 100000000.0
# Magic Tiles 3 : 50000000.0
# Jewels Star: OZ adventure : 1000000.0
# Granny : 50000000.0
# Dream League Soccer 2018 : 100000000.0
# Sweet Fruit Candy : 10000000.0
# Fruits Bomb : 10000000.0
# My Talking Tom : 500000000.0
# Sniper 3D Gun Shooter: Free Shooting Games - FPS : 100000000.0
# Shoot Bubble - Fruit Splash : 5000000.0
# Rider : 10000000.0
# Zombie Tsunami : 100000000.0
# Doodle Jump : 50000000.0
# Helix Jump : 100000000.0
# Crossy Road : 100000000.0
# Temple Run 2 : 500000000.0
# Talking Tom Gold Run : 100000000.0
# Alto's Adventure : 10000000.0
# DEER HUNTER 2018 : 10000000.0
# Cover Fire: offline shooting games for free : 10000000.0
# Anger of stick 5 : zombie : 50000000.0
# CATS: Crash Arena Turbo Stars : 50000000.0
# Soul Knight : 10000000.0
# Major Mayhem : 10000000.0
# DINO HUNTER: DEADLY SHORES : 10000000.0
# Extreme Match : 100000.0
# Power Rangers Dino Charge : 10000000.0
# Zombie Hunter: Post Apocalypse Survival Games : 10000000.0
# Agar.io : 100000000.0
# Zombie Hunter King : 1000000.0
# Battlelands Royale : 1000000.0
# Once Upon a Tower : 1000000.0
# TEKKEN™ : 5000000.0
# diep.io : 10000000.0
# Arrow.io : 10000000.0
# BEYBLADE BURST app : 10000000.0
# Dragon Hills : 10000000.0
# Bus Rush: Subway Edition : 100000000.0
# Tiny Archers : 5000000.0
# Runner 3d like : 100000.0
# War Robots : 50000000.0
# Dinosaur Simulator: Dino World : 5000000.0
# GUNSHIP BATTLE: Helicopter 3D : 50000000.0
# Quiz: Logo game : 10000000.0
# Jewels Legend - Match 3 Puzzle : 10000000.0
# Bubble Shooter : 10000000.0
# Bubble Shooter Genies : 5000000.0
# Blossom Blast Saga : 10000000.0
# Traffic Racer : 100000000.0
# Hill Climb Racing : 100000000.0
# Earn to Die 2 : 50000000.0
# Bubble Shooter 2 : 5000000.0
# Candy Bomb : 10000000.0
# Zombie Catchers : 10000000.0
# Gems or jewels ? : 10000000.0
# Angry Birds Rio : 100000000.0
# Candy Crush Jelly Saga : 50000000.0
# Cut the Rope FULL FREE : 100000000.0
# Hungry Shark Evolution : 100000000.0
# Power Pop Bubbles : 10000000.0
# Angry Birds Classic : 100000000.0
# Hill Climb Racing 2 : 100000000.0
# Jewels classic Prince : 5000000.0
# Fruit Block - Puzzle Legend : 10000000.0
# Bubble Shooter Space : 1000000.0
# Swamp Attack : 50000000.0
# 1LINE – One Line with One Touch : 10000000.0
# Stick War: Legacy : 10000000.0
# Bowmasters : 50000000.0
# Block Puzzle Classic Legend ! : 5000000.0
# Marble Woka Woka 2018 - Bubble Shooter Match 3 : 10000000.0
# Pixel Art: Color by Number Game : 10000000.0
# Super Jabber Jump 3 : 5000000.0
# Rush : 10000000.0
# Jetpack Joyride : 100000000.0
# DEAD TARGET: FPS Zombie Apocalypse Survival Games : 50000000.0
# Word Search : 50000000.0
# Rope Hero Return of a Legend : 1000000.0
# Draw a Stickman: EPIC 2 Free : 10000000.0
# UNO ™ & Friends : 50000000.0
# 4 in a Row : 500000.0
# Super Mario Run : 100000000.0
# STARDOM: THE A-LIST : 1000000.0
# Glow Hockey : 100000000.0
# Asphalt 8: Airborne : 100000000.0
# Lep's World 2 🍀🍀 : 100000000.0
# Law of Creation: A Playable Manga : 500000.0
# Real City Car Driver : 10000000.0
# Rolling Sky : 50000000.0
# 4 in a row : 5000000.0
# Four In A Line Free : 5000000.0
# Draw A Stickman : 1000000.0
# Four In A Line : 1000000.0
# Cardi B Piano Game : 10000.0
# MORTAL KOMBAT X : 10000000.0
# ► MultiCraft ― Free Miner! 👍 : 50000000.0
# Pixel Gun 3D: Survival shooter & Battle Royale : 50000000.0
# Perfect Piano : 50000000.0
# Critical Ops : 10000000.0
# FRONTLINE COMMANDO: D-DAY : 10000000.0
# Fruit Ninja® : 100000000.0
# Beach Buggy Blitz : 50000000.0
# Vector : 100000000.0
# Dr. Driving : 100000000.0
# D Day World War II Commando Survival Shooting : 100000.0
# Geometry Dash Meltdown : 50000000.0
# Bike Race Free - Top Motorcycle Racing Games : 100000000.0
# Smash Hit : 100000000.0
# Temple Run : 100000000.0
# Super Car F. Mod for MCPE : 50000.0
# Gangstar Vegas - mafia game : 50000000.0
# Rolling G Sky : 100000.0
# G-Switch 2 : 1000000.0
# G-Switch 3 : 100000.0
# G-Switch : 100000.0
# Radial-G : Infinity : 50000.0
# Geometry Dash Lite : 100000000.0
# Car Driving Simulator Drift : 1000000.0
# RC City Police Heavy Traffic Racer : 1000000.0
# Motorbike Driving Simulator 3D : 10000000.0
# Helix : 500000.0
# Solitaire! : 10000000.0
# iGun Pro -The Original Gun App : 10000000.0
# NinJump : 10000000.0
# Fidget Spinner : 10000000.0
# J Balvin Piano Tiles : 500.0
# Guess the song of J Balvin : 1000.0
# J-Stars Victory VS Guide : 10000.0
# KIM KARDASHIAN: HOLLYWOOD : 10000000.0
# Magic Tiles - TWICE Edition (K-Pop) : 100000.0
# Magic Tiles - Blackpink Edition (K-Pop) : 100000.0
# Korean Dungeon: K-Word 1000 : 10000.0
# Lep's World 🍀 : 50000000.0
# Ant Smasher by Best Cool & Fun Games : 100000000.0
# Cheating Tom 3 - Genius School : 10000000.0
# M3-X5-X6-M-İ3-İ8 RACİNG 2018 : 100000.0
# M-acceleration 3D Car Racing : 100000.0
# Super Hero M Craft Run : 100000.0
# Don't Hug Me I'm So Scared : 50000.0
# Rope'n'Fly 4 : 10000000.0
# Cops N Robbers - FPS Mini Game : 5000000.0
# Cops N Robbers 2 : 1000000.0
# Hide N Seek : Mini Game : 500000.0
# Rope'n'Fly 3 - Dusk Till Dawn : 10000000.0
# Drag'n'Boom : 1000000.0
# Cops N Robbers : 1000000.0
# Mopar Drag N Brag : 1000000.0
# Draw N Guess Multiplayer : 1000000.0
# Rock N' Cash Casino Slots -Free Vegas Slot Games : 100000.0
# Rock n Roll Music Quiz Game : 10000.0
# Drink-O-Tron The Drinking Game : 50000.0
# The Maze Runner : 10000000.0
# The Q - Live Trivia Game Network : 100000.0
# Q*bert: Rebooted : 1000000.0
# Gun Shoot War Q : 1000000.0
# DJMAX TECHNIKA Q - Music Game : 100000.0
# Stupid Zombies : 10000000.0
# Crime Wars S. Andreas : 500000.0
# Dino T-Rex : 10000000.0
# U-48 Submarine Commander Free : 500000.0
# Identity V : 1000000.0
# V for Voodoo : 1000000.0
# Sin City Crime Simulator V - Gangster : 100000.0
# The Gang Sniper V. Pocket Edition. : 500000.0
# San Andreas: Gang Crime V : 100000.0
# Grand Stickman Cover V : 100000.0
# Words With Friends Classic : 50000000.0
# Draw Something Classic : 50000000.0
# Extreme X Ray Robot Stunts : 5000000.0
# Casino X - Free Online Slots : 1000000.0
# X-WOLF : 100000.0
# Hero Fighter X : 500000.0
# Slendrina X : 1000000.0
# Robocar X Ray : 1000000.0
# Space X: Sky Wars of Air Force : 1000000.0
# Real Gangster Crime : 10000000.0
# Gangster Town : 5000000.0
# Rope Hero 3 : 5000000.0
# Experiment Z - Zombie : 10000000.0
# Z Champions : 1000000.0
# WithstandZ - Zombie Survival! : 1000000.0
# Zombie War Z : Hero Survival Rules : 100000.0
# DRAGON BALL Z DOKKAN BATTLE : 10000000.0
# Cube Z (Pixel Zombies) : 1000000.0
# GALAK-Z: Variant Mobile : 10000.0
# Reload: The Z-Team : 100000.0
# Rage Z: Multiplayer Zombie FPS Online Shooter : 500000.0
# Pixel Z Gunner 3D - Battle Survival Fps : 1000000.0
# Saiyan Z: Super SSJ Ultimate Combat : 10000.0
# Mini DAYZ: Zombie Survival : 1000000.0
# Route Z : 500000.0
# Dragon X Adventure: Warrior Z : 100000.0
# Ultimate Fighter Z : 5000.0
# Angry Birds Friends : 50000000.0
# Angry Birds Go! : 50000000.0
# Angry Birds Star Wars : 100000000.0
# Solitaire: Decked Out Ad Free : 500000.0
# AE Jewels 2: Island Adventures : 10000.0
# AE Bingo: Offline Bingo Games : 500000.0
# AE Jewels : 50000.0
# AE Spider Solitaire : 500000.0
# AE Coin Mania : Arcade Fun : 1000000.0
# Mupen64+AE FREE (N64 Emulator) : 1000000.0
# AE Lucky Fishing : 1000000.0
# AE Video Poker : 50000.0
# AE Solitaire : 50000.0
# AE Blackjack : 100000.0
# AE Gun Ball: arcade ball games : 1000000.0
# AE 3D MOTOR :Racing Games Free : 5000000.0
# AE GTO Racing : 100000.0
# AE 3D Moto 3 : 100000.0
# AE FreeCell : 10000.0
# AE City Jump : 10000.0
# AE Angry Chef : 10000.0
# AE Master Moto : 1000000.0
# AE Fishing Hunter : 1000.0
# Gun Strike Shoot : 10000000.0
# AG Drive 3D : 10000.0
# VR AG Racing for Cardboard : 1000.0
# AH-1 Viper Cobra Ops - helicopter flight simulator : 100000.0
# Ah! Coins : 50000.0
# Baby Game Animal Jam Free : 500.0
# Blackjack aj Poker : 1000.0
# Puppy Shooting an AK-47: Platformer Zombie Game : 1000.0
# Crisis Action: 2018 NO.1 FPS : 10000000.0
# AK-47 3D : 10000.0
# AK-47 Assult Rifle: Gun Shooting Simulator Game : 500.0
# Counter Terrorist Attack : 10000000.0
# AK Blackjack : 1000.0
# GUN ZOMBIE : 5000000.0
# Shoot Strike War Fire : 10000000.0
# I Am Innocent : 1000000.0
# What Am I? - Brain Teasers : 100000.0
# Who am I? (Biblical) : 500000.0
# Vikings: an Archer's Journey : 1000000.0
# Draw a Stickman: EPIC Free : 10000000.0
# THE KING OF FIGHTERS-A 2012(F) : 5000000.0
# Fast like a Fox : 5000000.0
# Ao Oni2 : 1000000.0
# Arena of Valor: 5v5 Arena Game : 10000000.0
# Mobile Legends: Bang Bang : 100000000.0
# Kill Shot Bravo: Sniper FPS : 10000000.0
# Carnivores: Dinosaur Hunter : 1000000.0
# Hopeless Land: Fight for Survival : 5000000.0
# Heroes Arena : 10000000.0
# Undead Assault : 100000.0
# Guess the Class 🔥 AQW : 1000.0
# Iron Blade : 10000000.0
# Evil Apples: A Dirty Card Game : 5000000.0
# Ghost Snap AR Horror Survival : 100000.0
# The Walking Dead: Our World : 1000000.0
# Ingress : 10000000.0
# Flat Pack : 100000.0
# Crayola Color Blaster : 1000.0
# Guns of Boom - Online Shooter : 10000000.0
# Guns Royale - Multiplayer Blocky Battle Royale : 100000.0
# Stack It AR : 100000.0
# Arcraft - AR Sandbox : 10000.0
# AR Tank Battle : 10000.0
# Sonic the Hedgehog™ Classic : 10000000.0
# Pacific Navy Fighter C.E. (AS) : 500000.0
# My OldBoy! Free - GBC Emulator : 5000000.0
# My Boy! Free - GBA Emulator : 10000000.0
# SAMURAI vs ZOMBIES DEFENSE : 5000000.0
# Five Nights at Freddy's 4 Demo : 10000000.0
# Five Nights at Freddy's 3 Demo : 10000000.0
# Nights at Cube Pizzeria 3D – 2 : 5000000.0
# Rivals at War: Firefight : 5000000.0
# 7 Nights at Pixel Pizzeria - 2 : 1000000.0
# Nights at Slender Pizzeria 3D : 100000.0
# One Night at Golden Freddy's : 100000.0
# Nights at Cube Pizzeria 3D – 4 : 500000.0
# Five Nights at Neighbor House : 100000.0
# Asylum Night Shift - Five Nights Survival : 5000000.0
# Two Nights at jumpscare : 100000.0
# Five Nights at Pizzeria : 100000.0
# Block Battles: Heroes at War - Multiplayer PVP : 500000.0
# Five Nights at Flappy's : 10000.0
# 5 Nights at Cube Pizzeria City : 100000.0
# Au Mobile: Audition Chính Hiệu : 1000000.0
# AU Mobile Indonesia : 1000000.0
# Super Dancer : 1000000.0
# Au-allstar for KR : 100000.0
# Super Dancer VN : 500000.0
# Love Dance : 1000000.0
# Avatar Musik : 1000000.0
# Armored Warfare: Assault : 100000.0
# Auction Wars : Storage King : 1000000.0
# iSniper 3D Arctic Warfare : 1000000.0
# Modern Action Commando 3D : 100000.0
# Call of Duty®: Heroes : 10000000.0
# AXE.IO - Brutal Survival Battleground : 500000.0
# Axe Champ : 10000.0
# Axe Champ Hit : 100.0
# Axe Champion : 5000.0
# Vikings Stickman Axe Fighting : 100000.0
# Axetatic - Axe Throwing Game : 1000.0
# Axe Champs! Wars : 50.0
# Axe Knight : 5000.0
# The Vikings : 1000000.0
# Knife&Axe Throwing : 50000.0
# Stickman and Axe : 50000.0
# Axe Throw: Flip Champ Axes Champion Throwing Games : 50.0
# Axe Man : 1000.0
# Dead Zombie Evil Killer:Axe : 10000.0
# Zlax.io Zombs Luv Ax : 500000.0
# Clash of Axe: Flippy Lumberjack Action X : 1000.0
# Flippy Axe : Flip The Knife & Axe Simulator : 100.0
# Cyborg AX-001 : 50.0
# Woodman Deluxe : 5000.0
# ¡Ay Metro! : 10000.0
# Ay Vamos - PJ. Balvin - Piano : 5.0
# San Andreas Crime Stories : 10000000.0
# Miami crime simulator : 10000000.0
# Strange Hero: Future Battle : 10000000.0
# Mad Day - Truck Distance Game : 5000000.0
# AZ Rockets : 10000.0
# Ba Cristi : 10000.0
# Banana Kong : 100000000.0
# Space Shooter : Galaxy Attack : 10000000.0
# BC Slots - The Lost Reels FREE : 10000.0
# Millionaire : Who want to be? : 100000.0
# Beauty Idol: Fashion Queen : 1000000.0
# Hard Time (Prison Sim) : 10000000.0
# Battlefield™ Companion : 10000000.0
# BF at Sea Refueled : 10000.0
# Bullet Force : 10000000.0
# BF Combat: Genesis : 100000.0
# Combat BF: Black Ops 3 : 500000.0
# BF Frontline City : 1000000.0
# Faketalk - Chatbot : 1000000.0
# Block Gun 3D: Call of Destiny : 1000000.0
# BLOOD & GLORY: IMMORTALS : 1000000.0
# Block Gun 3D: Ghost Ops : 5000000.0
# Rento - Dice Board Game Online : 10000000.0
# Survival Run with Bear Grylls : 5000000.0
# VIP Backgammon Free : Play Backgammon Online : 10000.0
# Out of Bounds BH Demo : 10.0
# Bi-Tank : 50.0
# Bike Rivals : 10000000.0
# Bingo Party - Free Bingo Games : 1000000.0
# BJ's Bingo & Gaming Casino : 10000.0
# BJ Bridge Free (2018) : 10000.0
# BJ Bridge Acol Beginner 2018 : 5000.0
# BJ Bridge Standard American 2018 : 1000.0
# BJ Strategy Tester : 100.0
# Cards Casino:Video Poker & BJ : 10000.0
# Real Casino:Slot,Keno,BJ,Poker : 50000.0
# Basic Strategy Training BJ 21 : 500.0
# BJ card game blackjack : 500.0
# BLACKJACK! : 10000000.0
# Blackjack : 1000000.0
# BlackJack -21 Casino Card Game : 100000.0
# BlackJack 21 Pro : 500000.0
# Ultimate BlackJack 3D FREE : 100000.0
# Blood Domination - BL Game : 10000.0
# Heirs & Graces : 5000.0
# Lust in Terror Manor - The Truth Unveiled | Otome : 10000.0
# BL!TZ - Endless : 100.0
# BL-ED: From BLUE to RED : 10.0
# Teen Patti by BL Games : 100000.0
# Word Hunt : 500.0
# Skip-Bo™ Free : 1000000.0
# Red Ball 4 : 50000000.0
# Skater Boy : 100000000.0
# Sic Bo Online! Free Casino : 100000.0
# Hambo : 5000000.0
# Sic Bo Rave : 10000.0
# Thai Sic Bo : 1000000.0
# Bounce Classic : 10000000.0
# Bomber Friends : 10000000.0
# Sic Bo (Tai Xiu) - Multiplayer Casino : 10000.0
# Hungry Shark World : 50000000.0
# Carros Rebaixados BR : 1000000.0
# Texas HoldEm Poker Deluxe (BR) : 10000.0
# Brick Breaker BR : 5.0
# Black Commando | Special Ops | FPS Shooting : 100000.0
# True Skateboarding Ride Skateboard Game Freestyle : 1000000.0
# Bullshit! (Free) : 10000.0
# Bullshite! : 10000.0
# Block Strike : 10000000.0
# BombSquad Remote : 1000000.0
# BS Tractor : 100.0
# BS Chopper : 100.0
# B@dL!bs Lite : 1000.0
# kick the buddy : 10000.0
# Bu Hangi Ünlü? : 10.0
# Bu Nedir ? : 50.0
# BU HANGİ ŞARKI ? - 2018 : 100.0
# Bu Hangi Oyun ? : 50.0
# Bu Hangi Youtuber ? : 1000.0
# Nedir Bu ? : 10.0
# Kick the Buddy : 50000000.0
# Bu Hangi Dizi ? : 1000.0
# Smashy Road: Arena : 5000000.0
# BW-Go Free : 10000.0
# BW-Joseki : 10000.0
# BW-DGS plugin : 1000.0
# BW-GnuGo : 5000.0
# BW Switch : 10.0
# C3-C4-PİCASSO-ELYSEE RACİNG : 1000.0
# Driving Cars Simulator Citroen : 100.0
# RC Monster Truck - Offroad Driving Simulator : 5000000.0
# Super Jabber Jump : 10000000.0
# Commando Adventure Assassin : 5000000.0
# Roulette Advisor LITE : 5000.0
# Mini Motor Racing WRT : 1000000.0
# BMX Boy Bike Stunt Rider Game : 10000.0
# World of Warriors: Duel : 500000.0
# Driving Zone : 1000000.0
# Color by Number – New Coloring Book : 5000000.0
# Car Race by Fun Games For Free : 1000000.0
# Slot Machines by IGG : 10000000.0
# Bingo by IGG: Top Bingo+Slots! : 5000000.0
# Voxel - 3D Color by Number & Pixel Coloring Book : 1000000.0
# BZ Zombie VR : 1000.0
# BZ Fingers : 50.0
# Sniper Gun Shot 3D: Impossible Missions : 100.0
# Elite Commando Shooting War : 100.0
# Animal Hunting: Sniper Shooting : 50.0
# Creative Destruction : 5000000.0
# Sonic CD Classic : 1000000.0
# ARK: Survival Evolved : 500000.0
# Grim Tales: The Wishes CE : 100000.0
# CrossFire: Legends : 5000000.0
# Special Forces Group 2 : 10000000.0
# Motocross Motorbike Simulator Offroad : 5000000.0
# Sermon on Proverbs CH Spurgeon : 10000.0
# Chicken Invaders 3 : 5000000.0
# Trovami se ci riesci : 10.0
# CJ: Strike Back : 1000000.0
# The Grand Wars: San Andreas : 1000000.0
# The Grand Way : 500000.0
# San Andreas City : Auto Theft Car gangster : 100000.0
# Miami Crime Vice Town : 10000000.0
# CJ Poker Odds Calculator : 50000.0
# Gangster City Auto Theft : 50000.0
# China Town Auto Theft 2 : 50000.0
# Grand Gangsters 3D : 10000000.0
# Gang Wars of San Andreas : 1000000.0
# Sin City Hero : Crime Simulator of Vegas : 100000.0
# Zombie Death Shooter : 1000000.0
# Project Grand Auto Town Sandbox Beta : 500000.0
# CONTRACT KILLER: ZOMBIES (NR) : 5000000.0
# CKZ ORIGINS : 1000000.0
# 211:CK Lite : 10.0
# CONTRACT KILLER: ZOMBIES : 5000000.0
# Can Knockdown 3 : 10000000.0
# Sky Streaker - Gumball : 5000000.0
# Just A Regular Arcade : 1000000.0
# Dreamland Arcade - Steven Universe : 500000.0
# Adventure Time Run : 1000000.0
# Glitch Fixers: Powerpuff Girls : 5000000.0
# StirFry Stunts - We Bare Bears : 10000000.0
# Angelo Rules - Crazy day : 1000000.0
# Multicraft Miner Exploration : 1000000.0
# Alex & Co Quiz : 1000.0
# Them Bombs: co-op board game play with 2-4 friends : 100000.0
# Chinese Chess ( Xiangqi Free ) : 50000.0
# Chinese Chess / Co Tuong : 500000.0
# Call of Mini™ Zombies 2 : 5000000.0
# 2-Player Co-op Zombie Shoot : 1000.0
# IV Go（get IV for Pokemon） : 1000000.0
# CP Trivia : 100.0
# CQ: Lost In Transmission : 10.0
# Palavras la cq : 100000.0
# Gunship Modern Combat 3D : 500000.0
# Sniper Killer Shooter : 10000000.0
# Snowboard Racing Free Fun Game : 100000.0
# Toughest Game Ever 2 : 5000000.0
# RIDE ZERO : 100000.0
# Critical Strike CS: Counter Terrorist Online FPS : 1000000.0
# Assault Line CS Online Fps Go : 1000000.0
# Standoff 2 : 10000000.0
# Counter Online FPS Game : 5000000.0
# Combat Strike CS 🔫 Counter Terrorist Attack FPS💣 : 100000.0
# Ultimate Quiz for CS:GO - Skins | Cases | Players : 100000.0
# Аim Training for CS : 100000.0
# Sniper Traning for CS GO : 50000.0
# Your rank CS:GO : 100000.0
# Mobile CS:GO : 100000.0
# Counter Terrorist Gun Strike CS: Special Forces : 10000.0
# Shooter Sniper CS - FPS Games : 1000000.0
# CS16Client : 500000.0
# Counter Attack - Multiplayer FPS : 1000000.0
# What's Your CS:GO rank? : 10000.0
# Map Callouts for CS:GO : 50000.0
# Quiz CS:GO players : 50000.0
# Puzzle for CS:GO : 10000.0
# CT-ART 4.0 (Chess Tactics 1200-2400 ELO) : 100000.0
# Moto Rider : 10000000.0
# Shadow Fight 2 : 100000000.0
# Crazy Wheels : 10000000.0
# Cartoon Wars: Blade : 5000000.0
# Racing CX : 500.0
# Freecell CY : 50000.0
# Cytus : 5000000.0
# Shadowverse CCG : 1000000.0
# SuperBikers 2 : 500000.0
# Dan the Man: Action Platformer : 10000000.0
# Geometry Dash SubZero : 10000000.0
# Metal Soldiers 2 : 10000000.0
# Quiz TRUE or FALSE : 50000.0
# Run Sausage Run! : 10000000.0
# Knife Hit : 10000000.0
# The Visitor : 5000000.0
# Just Dance Now : 10000000.0
# DRAGON BALL LEGENDS : 5000000.0
# DB Ultra Saiyan Battle : 1000.0
# Injustice 2 : 5000000.0
# Injustice: Gods Among Us : 10000000.0
# Ultimate DC Challenge : 10000.0
# Justice League Action Run : 1000000.0
# Quiz DC : 1000.0
# MARVEL Contest of Champions : 50000000.0
# MARVEL Avengers Academy : 10000000.0
# DC Universe Quiz : 500.0
# Power Rangers: Legacy Wars : 10000000.0
# WDAMAGE: Car Crash Engine : 1000000.0
# Word Search multilingual : 1000000.0
# Piano Free - Keyboard with Magic Tiles Music Games : 50000000.0
# Racing in Car 2 : 50000000.0
# Bike Racing 3D : 50000000.0
# Truck Driver Cargo : 10000000.0
# Checkers : 10000000.0
# Scratch Logo Quiz. Challenging brain puzzle : 10000000.0
# DF Squid : 100.0
# DG Mobile : 1000.0
# Destroy Gunners Σ : 1000000.0
# DH Texas Poker - Texas Hold'em : 10000000.0
# DEER HUNTER CLASSIC : 50000000.0
# DEER HUNTER RELOADED : 5000000.0
# DH Pineapple Poker OFC : 100000.0
# Call of Mini™ Dino Hunter : 10000000.0
# Bike Mayhem Free : 10000000.0
# Car Crash III Beam DH Real Damage Simulator 2018 : 10000.0
# DEER HUNTER CHALLENGE : 5000000.0
# Defender : 10000000.0
# Texas HoldEm Poker Deluxe : 10000000.0
# Deck Heroes: Legacy : 10000000.0
# Shred! Downhill Mountainbiking : 1000000.0
# Archery Physics Objects Destruction Apple shooter : 100000.0
# Fancy Pants Adventures : 1000000.0
# Lep's World 3 🍀🍀🍀 : 50000000.0
# Robbery Bob : 10000000.0
# Nyan Cat: Lost In Space : 10000000.0
# DK Quiz : 50000.0
# Super DK vs Kong Brother Advanced Free Classic : 10000.0
# DM EVOLUTION : 10000.0
# DM Adventure : 10.0
# Destiny Ninja Shall we date otome games love story : 500000.0
# Free Poker Games : Downtown Casino - Texas Holdem : 50000.0
# NARUTO X BORUTO NINJA VOLTAGE : 5000000.0
# Does not Commute : 5000000.0
# Kung Fu Do Fighting : 10000000.0
# How well do you know me? : 100000.0
# Dude Perfect 2 : 10000000.0
# Endless Ducker : 500000.0
# that's lit : 100000.0
# Dash Quest Heroes : 500000.0
# Jungle book-The Great Escape : 100000.0
# Bunny Skater : 10000000.0
# The Walking Zombie: Dead City : 1000000.0
# Dr. Parking 4 : 50000000.0
# Dr. Driving 2 : 10000000.0
# Dr. Parker : Parking Simulator : 1000000.0
# Dr. Parker : Real car parking simulation : 1000000.0
# Dr. Rocket : 1000000.0
# Dr. Dominoes : 500000.0
# Dr. Gomoku : 5000000.0
# Dr. Chess : 1000000.0
# Dr Dre - Beatmaker : 10000.0
# Dr Driving Racer : 10000.0
# Dr. Shogi : 1000000.0
# NDS Emulator - For Android 6 : 1000000.0
# Free DS Emulator : 1000000.0
# nds4droid : 10000000.0
# MegaNDS (NDS Emulator) : 500000.0
# EmuBox - Fast Retro Emulator : 50000.0
# Simple x3DS Emulator - BETA : 50000.0
# DS Tower Defence : 100000.0
# RetroArch : 1000000.0
# Wheelie Challenge : 5000000.0
# Sword of Chaos - Lame du Chaos : 100000.0
# Hotel Insanity : 100000.0
# Shoot! DX - lights for FREE : 100.0
# American Sniper City Fight Shooting Assassin : 50000.0
# Street Skater 3D : 10000000.0
# DZ-JOKER : 100.0
# Super ball DZ : 1000.0
# Ludo Dz : 500.0
# Need for Speed™ No Limits : 50000000.0
# Peggle Blast : 5000000.0
# Heroes of Dragon Age : 1000000.0
# SCRABBLE : 5000000.0
# Asphalt Xtreme: Rally Racing : 10000000.0
# Modern Combat 5: eSports FPS : 100000000.0
# Mass Effect: Andromeda APEX HQ : 100000.0
# Mirror’s Edge™ Companion : 100000.0
# Gear.Club - True Racing : 1000000.0
# Mental Hospital:EB 2 Lite : 100000.0
# EC Mover : 10.0
# EF Jumper : 100.0
# E.G. Chess Free : 10000.0
# L.A. Crime Stories 2 Mad City Crime : 100000.0
# LA Stories 4 New Order Sandbox 2018 : 1000000.0
# L.A. Crime Stories Mad City Crime : 1000000.0
# Miraculous Ladybug & Cat Noir - The Official Game : 10000000.0
# Betul Ke Bohong Eh? : 100000.0
# Eh Amego! : 500000.0
# MazeMilitia Classic Multiplayer Shooting Game : 50000.0
# ZOMBIE RIPPER : 500000.0
# Horror Hospital : 1000000.0
# Mad Skills Motocross : 1000000.0
# Pineapple Pen : 10000000.0
# Guess The Emoji : 5000000.0
# Camping RV Caravan Parking 3D : 500000.0
# Grand Bat Superhero Flying Assault Rescue Mission : 500000.0
# Zombie Frontier : 10000000.0
# RUN JUMP RUN-fun games for free : 100000.0
# Tamago egg : 5000.0
# Let's Poke The Egg : 1000000.0
# Survival: Prison Escape : 10000000.0
# TAMAGO Monsters Returns : 1000000.0
# Traffic Sniper Counter Attack : 1000000.0
# Sudoku Master : 1000000.0
# Jungle Monkey Run : 10000000.0
# Ez Mirror Match : 500000.0
# CNY Slots : Gong Xi Fa Cai 发财机 : 5000.0
# Golden HoYeah Slots - Real Casino Slots : 5000000.0
# FaFaFa™ Gold Casino: Free slot machines : 1000000.0
# Heart of Vegas™ Slots – Free Slot Casino Games : 10000000.0
# Garena Free Fire : 100000000.0
# FG SPINNER : 10.0
# BROTHER IN WARS: GUNNER CITY WARLORDS : 1000000.0
# Angry Birds Space HD : 5000000.0
# Police Car Driver : 10000000.0
# Modern Sniper Strike: Best Commando Action 2k18 : 10000.0
# Moto Fighter 3D : 10000000.0
# BMX Boy : 50000000.0
# Crazy Bike attack Racing New: motorcycle racing : 5000000.0
# Fields of Battle : 1000000.0
# Family Guy The Quest for Stuff : 10000000.0
# Toy Attack : 500000.0
# SnowMobile Parking Adventure : 1000000.0
# Zombie Sniper 3D III : 500000.0
# Shoot Hunter-Gun Killer : 50000000.0
# Fast Motorcycle Driver 2016 : 1000000.0
# Forgotten Hill: Fall : 50000.0
# Forgotten Hill Mementoes : 100000.0
# Forgotten Hill: Surgery : 100000.0
# Forgotten Hill: Puppeteer : 100000.0
# FJ Final Join , Circles Game : 1000.0
# Offroad drive : 4x4 driving game : 100000.0
# Rope Hero: Vice Town : 10000000.0
# Drive 4x4 Luxury SUV Jeep : 500000.0
# Motocross Mayhem : 1000000.0
# Dino Defends king 3 – Dinosaur T rex Hunter Games : 50000.0
# Block Gun 3D: Haunted Hollow : 1000000.0
# Navy Gunner Shoot War 3D : 10000000.0
# Drift Legends : 1000000.0
# FK (FlightKid) : 10.0
# Toy Truck Rally 3D : 50000000.0
# PRO MX MOTOCROSS 2 : 5000000.0
# FRONTLINE COMMANDO : 10000000.0
# Gun Builder ELITE : 1000000.0
# Magnum 3.0 Gun Custom SImulator : 1000000.0
# Gun Club Armory : 1000000.0
# Armed Cam Gun Pack : 10000.0
# Fo Fo Fish : 50.0
# 4x4 Jeep Racer : 1000000.0
# Frontline Terrorist Battle Shoot: Free FPS Shooter : 1000000.0
# Mad Dash Fo' Cash : 100.0
# Race Manager FP : 5000.0
# FP Runner : 1000.0
# Modern Counter Terrorist FPS Shoot : 100000.0
# Monster Ride Pro : 10.0
# BEBONCOOL GAMEPAD V1.0 : 100000.0
# Modern Strike Online : 10000000.0
# Modern Counter Terror Attack – Shooting Game : 50000.0
# Big Hunter : 10000000.0
# Modern Counter Global Strike 3D : 50000.0
# Modern Counter Global Strike 3D V2 : 50000.0
# Winter Wonderland : 50000.0
# Soccer Clubs Logo Quiz : 1000000.0
# Sid Story : 500000.0
# Fatal Raid - No.1 Mobile FPS : 1000000.0
# Poker Pro.Fr : 100000.0

# %% [markdown]
# In this project, our purpose was to examine the apps data taken from App Store and Google Play in order to offer a genre for our company to build a new app for the market. Our company gathers most of its income through in-app ads and English speaking countries, therefore we focused on those apps filtering the rest from the data.
#
# We concluded that, apps which have high number of users have genres like communication, video streaming etc and those fields are heavily dominated by huge companies already like Facebook and Google. Therefore we offered the company to build a game app which we see more room to get success in both markets.
